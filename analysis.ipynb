# %%
import numpy as np
import pandas as pd

# %%
patients = pd.read_csv('assets\IndividualDetails.csv')
patients.head()
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\I'
# <>:1: SyntaxWarning: invalid escape sequence '\I'
# C:\Users\yashr\AppData\Local\Temp\ipykernel_19752\1952864076.py:1: SyntaxWarning: invalid escape sequence '\I'
#   patients = pd.read_csv('assets\IndividualDetails.csv')
#    id government_id diagnosed_date  age gender             detected_city  \
# 0   0      KL-TS-P1     30/01/2020   20      F                  Thrissur
# 1   1      KL-AL-P1     02/02/2020  NaN    NaN                 Alappuzha
# 2   2      KL-KS-P1     03/02/2020  NaN    NaN                 Kasaragod
# 3   3         DL-P1     02/03/2020   45      M  East Delhi (Mayur Vihar)
# 4   4         TS-P1     02/03/2020   24      M                 Hyderabad
#
#   detected_district detected_state nationality current_status  \
# 0          Thrissur         Kerala       India      Recovered
# 1         Alappuzha         Kerala       India      Recovered
# 2         Kasaragod         Kerala       India      Recovered
# ...

# %%
patients['current_status'].value_counts()
# Out:
# current_status
# Hospitalized    8301
# Recovered        139
# Deceased          30
# Migrated           1
# Name: count, dtype: int64

# %%
total = patients.shape[0]
active = patients[patients['current_status'] == 'Hospitalized'].shape[0]
active = patients[patients['current_status'] == 'Recovered'].shape[0]
active = patients[patients['current_status'] == 'Deceased'].shape[0]
# Out:
# (8301, 12)

# %%
patients_bar = patients['detected_state'].value_counts().reset_index()

# %%
npat = patients[patients['current_status'] == 'Hospitalized']
patients_bar = npat['detected_state'].value_counts().reset_index()

# %%
patients_bar
# Out:
#                  detected_state  count
# 0                   Maharashtra   1757
# 1                         Delhi   1065
# 2                    Tamil Nadu    962
# 3                     Rajasthan    696
# 4                Madhya Pradesh    527
# 5                     Telangana    501
# 6                       Gujarat    463
# 7                 Uttar Pradesh    445
# 8                Andhra Pradesh    403
# 9                        Kerala    313
# 10            Jammu and Kashmir    223
# 11                    Karnataka    181
# 12                      Haryana    167
# 13                       Punjab    156
# 14                  West Bengal    128
# 15                        Bihar     63
# 16                       Odisha     53
# 17                  Uttarakhand     34
# 18             Himachal Pradesh     30
# 19                        Assam     29
# 20                 Chhattisgarh     24
# 21                   Chandigarh     19
# 22                    Jharkhand     17
# ...
